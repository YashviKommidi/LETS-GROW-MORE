# %% [markdown]
# <a href="https://colab.research.google.com/github/YashviKommidi/LGMVIP-DataScience/blob/main/Exploratory_Data_Analysis_on_Dataset_Terrorism_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS ON DATASET TERRORISM INTERMEDIATE LEVEL TASK-1**

# %% [markdown]
# # importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading Data

# %%
terr=pd.read_csv("/content/globalterrorismdb_0718dist.csv",encoding='latin1')

# %%
terr
# Out:
#              eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0       197000000001   1970       7     2  ...        0         0       0      NaN
# 1       197000000002   1970       0     0  ...        1         1       1      NaN
# 2       197001000001   1970       1     0  ...       -9         1       1      NaN
# 3       197001000002   1970       1     0  ...       -9         1       1      NaN
# 4       197001000003   1970       1     0  ...       -9         1       1      NaN
# ...              ...    ...     ...   ...  ...      ...       ...     ...      ...
# 181686  201712310022   2017      12    31  ...        0         0       0      NaN
# 181687  201712310029   2017      12    31  ...       -9         1       1      NaN
# 181688  201712310030   2017      12    31  ...        0         0       0      NaN
# 181689  201712310031   2017      12    31  ...       -9         0      -9      NaN
# ...

# %%
terr.head(2)
# Out:
#         eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0  197000000001   1970       7     2  ...        0         0       0      NaN
# 1  197000000002   1970       0     0  ...        1         1       1      NaN
#
# [2 rows x 135 columns]

# %% [markdown]
# # understanding the data

# %%
terr.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
terr.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %%
terr.head()
# Out:
#         eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0  197000000001   1970       7     2  ...        0         0       0      NaN
# 1  197000000002   1970       0     0  ...        1         1       1      NaN
# 2  197001000001   1970       1     0  ...       -9         1       1      NaN
# 3  197001000002   1970       1     0  ...       -9         1       1      NaN
# 4  197001000003   1970       1     0  ...       -9         1       1      NaN
#
# [5 rows x 135 columns]

# %%
terr.rename(columns={'iyear':'Year','imonth':'Month','iday':"day",'gname':'Group','country_txt':'Country','region_txt':'Region','provstate':'State','city':'City','latitude':'latitude',
    'longitude':'longitude','summary':'summary','attacktype1_txt':'Attacktype','targtype1_txt':'Targettype','weaptype1_txt':'Weapon','nkill':'kill',
     'nwound':'Wound'},inplace=True)

# %%
terr = terr[['Year','Month','day','Country','State','Region','City','latitude','longitude',"Attacktype",'kill',
               'Wound','target1','summary','Group','Targettype','Weapon','motive']]

# %%
terr.shape
# Out:
# (181691, 18)

# %%
terr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 18 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Year        181691 non-null  int64
#  1   Month       181691 non-null  int64
#  2   day         181691 non-null  int64
#  3   Country     181691 non-null  object
#  4   State       181270 non-null  object
#  5   Region      181691 non-null  object
#  6   City        181257 non-null  object
#  7   latitude    177135 non-null  float64
#  8   longitude   177134 non-null  float64
#  9   Attacktype  181691 non-null  object
#  10  kill        171378 non-null  float64
#  11  Wound       165380 non-null  float64
#  12  target1     181055 non-null  object
#  13  summary     115562 non-null  object
#  14  Group       181691 non-null  object
#  15  Targettype  181691 non-null  object
#  16  Weapon      181691 non-null  object
#  17  motive      50561 non-null   object
# ...

# %%
terr.isnull().sum()
# Out:
# Year               0
# Month              0
# day                0
# Country            0
# State            421
# Region             0
# City             434
# latitude        4556
# longitude       4557
# Attacktype         0
# kill           10313
# Wound          16311
# target1          636
# summary        66129
# Group              0
# Targettype         0
# Weapon             0
# motive        131130
# dtype: int64

# %%
terr.describe()
# Out:
#                 Year          Month  ...           kill          Wound
# count  181691.000000  181691.000000  ...  171378.000000  165380.000000
# mean     2002.638997       6.467277  ...       2.403272       3.167668
# std        13.259430       3.388303  ...      11.545741      35.949392
# min      1970.000000       0.000000  ...       0.000000       0.000000
# 25%      1991.000000       4.000000  ...       0.000000       0.000000
# 50%      2009.000000       6.000000  ...       0.000000       0.000000
# 75%      2014.000000       9.000000  ...       2.000000       2.000000
# max      2017.000000      12.000000  ...    1570.000000    8191.000000
#
# [8 rows x 7 columns]

# %%
missing_values = (((terr.isnull().sum()).sum())/terr.size)*100
missing_values
# Out:
# 7.169895897736021

# %%
for i in terr.columns:
    print(i,terr[i].nunique())
# Out:
# Year 47
# Month 13
# day 32
# Country 205
# State 2855
# Region 12
# City 36674
# latitude 48322
# longitude 48039
# Attacktype 9
# kill 205
# Wound 238
# target1 86006
# summary 112492
# Group 3537
# Targettype 22
# Weapon 12
# motive 14490

# %%
terr['Wound'] = terr['Wound'].fillna(0).astype(int)
terr['kill'] = terr['kill'].fillna(0).astype(int)

# %%
terr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 18 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Year        181691 non-null  int64
#  1   Month       181691 non-null  int64
#  2   day         181691 non-null  int64
#  3   Country     181691 non-null  object
#  4   State       181270 non-null  object
#  5   Region      181691 non-null  object
#  6   City        181257 non-null  object
#  7   latitude    177135 non-null  float64
#  8   longitude   177134 non-null  float64
#  9   Attacktype  181691 non-null  object
#  10  kill        181691 non-null  int64
#  11  Wound       181691 non-null  int64
#  12  target1     181055 non-null  object
#  13  summary     115562 non-null  object
#  14  Group       181691 non-null  object
#  15  Targettype  181691 non-null  object
#  16  Weapon      181691 non-null  object
#  17  motive      50561 non-null   object
# ...

# %%
terr.head(10)
# Out:
#    Year  Month  ...      Weapon                                          motive
# 0  1970      7  ...     Unknown                                             NaN
# 1  1970      0  ...     Unknown                                             NaN
# 2  1970      1  ...     Unknown                                             NaN
# 3  1970      1  ...  Explosives                                             NaN
# 4  1970      1  ...  Incendiary                                             NaN
# 5  1970      1  ...    Firearms  To protest the Cairo Illinois Police Deparment
# 6  1970      1  ...    Firearms                                             NaN
# 7  1970      1  ...  Explosives                                             NaN
# 8  1970      1  ...  Incendiary     To protest the War in Vietnam and the draft
# 9  1970      1  ...  Incendiary     To protest the War in Vietnam and the draft
#
# [10 rows x 18 columns]

# %% [markdown]
# # Representing Data

# %%
attack = terr.Country.value_counts()[:10]
attack
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
terr['Country'].value_counts()
# Out:
# Iraq                 24636
# Pakistan             14368
# Afghanistan          12731
# India                11960
# Colombia              8306
#                      ...
# New Hebrides             1
# Wallis and Futuna        1
# Falkland Islands         1
# North Korea              1
# South Vietnam            1
# Name: Country, Length: 205, dtype: int64

# %%
terr['State'].value_counts()
# Out:
# Baghdad                           7645
# Northern Ireland                  4498
# Unknown                           4290
# Balochistan                       3710
# Saladin                           3411
#                                   ...
# Phetchaburi                          1
# Niamey (Administrative Region)       1
# El Bordj (District)                  1
# Lodz                                 1
# Parita-Merivalja                     1
# Name: State, Length: 2855, dtype: int64

# %%
terr['Region'].value_counts()
# Out:
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: Region, dtype: int64

# %%
terr['Year'].value_counts()
# Out:
# 2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# 2012     8522
# 2011     5076
# 1992     5071
# 2010     4826
# 2008     4805
# 2009     4721
# 1991     4683
# 1989     4324
# 1990     3887
# 1988     3721
# 1984     3495
# 1994     3456
# 2007     3242
# 1997     3197
# 1987     3183
# 1995     3081
# 1996     3058
# 1985     2915
# 1983     2870
# 1986     2860
# 2006     2758
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 2005     2017
# 2001     1906
# 2000     1814
# 1978     1526
# 1999     1395
# 2002     1333
# 1977     1319
# 2003     1278
# 2004     1166
# 1998      934
# 1976      923
# 1975      740
# 1970      651
# 1974      581
# 1972      568
# 1973      473
# 1971      471
# Name: Year, dtype: int64

# %%
terr['City'].value_counts()
# Out:
# Unknown        9775
# Baghdad        7589
# Karachi        2652
# Lima           2359
# Mosul          2265
#                ...
# El Nino           1
# Mapaso            1
# Ramat Hadar       1
# Panipora          1
# Toru Dhok         1
# Name: City, Length: 36674, dtype: int64

# %%
year = terr['Year'].unique()
years_count = terr['Year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,10))
sns.barplot(x = year,
           y = years_count,
           palette = "tab10")
plt.xticks(rotation = 50)
plt.xlabel('Attacking]Year',fontsize=20)
plt.ylabel('Number of Attacks Each Year',fontsize=20)
plt.title('Attacks In Years',fontsize=30)
plt.show()

# %%
plt.figure(figsize = (11,6))
sns.histplot(terr['Attacktype'], palette='cubehelix')
plt.title('Attacktype',fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %%
terr['Wound'] = terr['Wound'].fillna(0)
terr['kill'] = terr['kill'].fillna(0)

# %%
terr['Casualities'] = terr['kill'] + terr['Wound']

# %%
terr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   State        181270 non-null  object
#  5   Region       181691 non-null  object
#  6   City         181257 non-null  object
#  7   latitude     177135 non-null  float64
#  8   longitude    177134 non-null  float64
#  9   Attacktype   181691 non-null  object
#  10  kill         181691 non-null  int64
#  11  Wound        181691 non-null  int64
#  12  target1      181055 non-null  object
#  13  summary      115562 non-null  object
#  14  Group        181691 non-null  object
#  15  Targettype   181691 non-null  object
#  16  Weapon       181691 non-null  object
#  17  motive       50561 non-null   object
# ...

# %%
terr.describe()
# Out:
#                 Year          Month  ...          Wound    Casualities
# count  181691.000000  181691.000000  ...  181691.000000  181691.000000
# mean     2002.638997       6.467277  ...       2.883291       5.150151
# std        13.259430       3.388303  ...      34.309746      40.555414
# min      1970.000000       0.000000  ...       0.000000       0.000000
# 25%      1991.000000       4.000000  ...       0.000000       0.000000
# 50%      2009.000000       6.000000  ...       0.000000       1.000000
# 75%      2014.000000       9.000000  ...       2.000000       4.000000
# max      2017.000000      12.000000  ...    8191.000000    9574.000000
#
# [8 rows x 8 columns]

# %%
df = terr[['Year','kill']].groupby(['Year']).sum()
fig, ax4 = plt.subplots(figsize=(60,20))
df.plot(kind='bar',alpha=0.7,ax=ax4)
plt.xticks(rotation = 60)
plt.title("People Died Due To Attack",fontsize=25)
plt.ylabel("Number of killed peope",fontsize=20)
plt.xlabel('Year',fontsize=30)
top_side = ax4.spines["top"]
top_side.set_visible(False)
right_side = ax4.spines["right"]
right_side.set_visible(False)

# %%
terr['City'].value_counts().to_frame().sort_values('City',axis=0,ascending=False).head(10).plot(kind='bar',figsize=(30,20),color='red')
plt.xticks(rotation = 30)
plt.xlabel("City",fontsize=35)
plt.ylabel("Number of attack",fontsize=35)
plt.title("Top 10 most effected city",fontsize=30)
plt.show()

# %%
terr['Attacktype'].value_counts().plot(kind='bar',figsize=(30,30),color='purple')
plt.xticks(rotation = 30)
plt.xlabel("Attacktype",fontsize=35)
plt.ylabel("Number of attack",fontsize=35)
plt.title("Name of attacktype",fontsize=30)
plt.show()

# %%
terr[['Attacktype','Wound']].groupby(["Attacktype"],axis=0).sum().plot(kind='bar',figsize=(20,10),color=['green'])
plt.xticks(rotation=50)
plt.title("Number of wounded  ",fontsize=20)
plt.ylabel('Number of people',fontsize=15)
plt.xlabel('Attack type',fontsize=15)
plt.show()

# %%
terr[['Attacktype','kill']].groupby(["Attacktype"],axis=0).sum().plot(kind='bar',figsize=(20,10),color=['orange'])
plt.xticks(rotation=50)
plt.title("Number of killed ",fontsize=30)
plt.ylabel('Number of people',fontsize=35)
plt.xlabel('Attack type',fontsize=35)
plt.show()

# %%
data=terr[['Group','Country','kill']]
data=data.groupby(['Group','Country'],axis=0).sum().sort_values('kill',ascending=False).drop('Unknown').reset_index().head(10)
data
# Out:
#                                               Group      Country   kill
# 0       Islamic State of Iraq and the Levant (ISIL)         Iraq  31058
# 1                                           Taliban  Afghanistan  29269
# 2                                        Boko Haram      Nigeria  16917
# 3                                 Shining Path (SL)         Peru  11595
# 4           Liberation Tigers of Tamil Eelam (LTTE)    Sri Lanka  10928
# 5                                        Al-Shabaab      Somalia   8176
# 6  Farabundo Marti National Liberation Front (FMLN)  El Salvador   8019
# 7       Islamic State of Iraq and the Levant (ISIL)        Syria   6883
# 8                 Nicaraguan Democratic Force (FDN)    Nicaragua   6630
# 9                   Tehrik-i-Taliban Pakistan (TTP)     Pakistan   6014

# %%
CKill = terr.pivot_table(columns='Country', values='kill', aggfunc='sum')
CKill
# Out:
# Country  Afghanistan  Albania  Algeria  ...  Zaire  Zambia  Zimbabwe
# kill           39384       42    11066  ...    324      70       154
#
# [1 rows x 205 columns]

# %%
tKill = terr.pivot_table(columns='Attacktype', values='kill', aggfunc='sum')
tKill
# Out:
# Attacktype  Armed Assault  Assassination  ...  Unarmed Assault  Unknown
# kill               160297          24920  ...              880    32381
#
# [1 rows x 9 columns]
